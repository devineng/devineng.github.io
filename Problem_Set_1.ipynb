# %% [markdown]
# <a href="https://colab.research.google.com/github/devineng/devineng.github.io/blob/master/Problem_Set_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.12, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 7 items
#
# submission_test.py FFFFFFF                                               [100%]
#
# =================================== FAILURES ===================================
# ________________________________ test_bibonacci ________________________________
#
#     def test_bibonacci():
# >       assert submission.bibonacci(0) == [1]
# E       assert None == [1]
# E        +  where None = <function bibonacci at 0x7f260904a0e0>(0)
# E        +    where <function bibonacci at 0x7f260904a0e0> = submission.bibonacci
#
# submission_test.py:5: AssertionError
# ______________________________ test_not_bibonacci ______________________________
#
#     def test_not_bibonacci():
# >       assert submission.not_bibonacci(0) == [0]
# E       assert None == [0]
# ...
